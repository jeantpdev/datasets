# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./synthetic_financial_data.csv')

# %%
data
# Out:
#       transaction_id  customer_id  merchant_id   amount     transaction_time  \
# 0                  1         1082         2027  5758.59  2023-01-01 00:00:00
# 1                  2         1015         2053  1901.56  2023-01-01 00:00:01
# 2                  3         1004         2035  1248.86  2023-01-01 00:00:02
# 3                  4         1095         2037  7619.05  2023-01-01 00:00:03
# 4                  5         1036         2083  1890.10  2023-01-01 00:00:04
# ...              ...          ...          ...      ...                  ...
# 9995            9996         1056         2023  8935.28  2023-01-01 02:46:35
# 9996            9997         1053         2026    30.15  2023-01-01 02:46:36
# 9997            9998         1041         2034  6333.64  2023-01-01 02:46:37
# 9998            9999         1009         2019  2837.13  2023-01-01 02:46:38
# 9999           10000         1082         2070  7209.43  2023-01-01 02:46:39
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           10000 non-null  int64
#  1   customer_id              10000 non-null  int64
#  2   merchant_id              10000 non-null  int64
#  3   amount                   10000 non-null  float64
#  4   transaction_time         10000 non-null  object
#  5   is_fraudulent            10000 non-null  int64
#  6   card_type                10000 non-null  object
#  7   location                 10000 non-null  object
#  8   purchase_category        10000 non-null  object
#  9   customer_age             10000 non-null  int64
#  10  transaction_description  10000 non-null  object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 859.5+ KB

# %%
data['transaction_time'] = pd.to_datetime(data['transaction_time'])

# %%
data[['amount', 'customer_age']].describe()
# Out:
#              amount  customer_age
# count  10000.000000  10000.000000
# mean    4958.381617     44.047500
# std     2899.699675     15.321707
# min       10.610000     18.000000
# 25%     2438.175000     31.000000
# 50%     4943.945000     44.000000
# 75%     7499.312500     57.000000
# max     9999.750000     70.000000

# %%
data_fraudulenta = data['is_fraudulent'].value_counts().reset_index()
data_fraudulenta
# Out:
#    is_fraudulent  count
# 0              1   5068
# 1              0   4932

# %%
plt.title("Cantidad de data fraudulenta vs No Fraudulenta")
plt.bar(["Fraudulento", "No fraudulento"], data_fraudulenta['count'], color = 'skyblue')
plt.xlabel("Tipo")
plt.ylabel("Cantidad")
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
data
# Out:
#       transaction_id  customer_id  merchant_id   amount    transaction_time  \
# 0                  1         1082         2027  5758.59 2023-01-01 00:00:00
# 1                  2         1015         2053  1901.56 2023-01-01 00:00:01
# 2                  3         1004         2035  1248.86 2023-01-01 00:00:02
# 3                  4         1095         2037  7619.05 2023-01-01 00:00:03
# 4                  5         1036         2083  1890.10 2023-01-01 00:00:04
# ...              ...          ...          ...      ...                 ...
# 9995            9996         1056         2023  8935.28 2023-01-01 02:46:35
# 9996            9997         1053         2026    30.15 2023-01-01 02:46:36
# 9997            9998         1041         2034  6333.64 2023-01-01 02:46:37
# 9998            9999         1009         2019  2837.13 2023-01-01 02:46:38
# 9999           10000         1082         2070  7209.43 2023-01-01 02:46:39
#
# ...

# %%
df_data_fraudulenta = data[(data['is_fraudulent'] == 1)]
df_data_fraudulenta
# Out:
#       transaction_id  customer_id  merchant_id   amount    transaction_time  \
# 1                  2         1015         2053  1901.56 2023-01-01 00:00:01
# 2                  3         1004         2035  1248.86 2023-01-01 00:00:02
# 3                  4         1095         2037  7619.05 2023-01-01 00:00:03
# 4                  5         1036         2083  1890.10 2023-01-01 00:00:04
# 5                  6         1032         2021  8487.68 2023-01-01 00:00:05
# ...              ...          ...          ...      ...                 ...
# 9990            9991         1020         2057  3377.98 2023-01-01 02:46:30
# 9993            9994         1098         2001  6563.32 2023-01-01 02:46:33
# 9995            9996         1056         2023  8935.28 2023-01-01 02:46:35
# 9998            9999         1009         2019  2837.13 2023-01-01 02:46:38
# 9999           10000         1082         2070  7209.43 2023-01-01 02:46:39
#
# ...

# %%
tipo_comercio_fraude = df_data_fraudulenta.groupby('is_fraudulent')['purchase_category'].value_counts().reset_index()
tipo_comercio_fraude
# Out:
#    is_fraudulent purchase_category  count
# 0              1         Groceries    896
# 1              1       Gas Station    874
# 2              1            Travel    856
# 3              1            Retail    853
# 4              1   Online Shopping    804
# 5              1        Restaurant    785

# %%
tipo_comercio_fraude = df_data_fraudulenta['purchase_category'].value_counts().reset_index()
tipo_comercio_fraude
# Out:
#   purchase_category  count
# 0         Groceries    896
# 1       Gas Station    874
# 2            Travel    856
# 3            Retail    853
# 4   Online Shopping    804
# 5        Restaurant    785

# %%
plt.pie(tipo_comercio_fraude['count'], labels=tipo_comercio_fraude['purchase_category'], autopct='%1d%%', startangle= 140)
plt.legend(tipo_comercio_fraude['purchase_category'], title="Categories", loc="center", bbox_to_anchor=(1.1, 0, 0.5, 1))

# %%
tipo_tarjeta_fraude = df_data_fraudulenta['card_type'].value_counts()
tipo_tarjeta_fraude
# Out:
# card_type
# Discover            1329
# Visa                1264
# MasterCard          1243
# American Express    1232
# Name: count, dtype: int64

# %%
plt.title("Tipo de tarjeta usada en el fraude")
plt.bar(tipo_tarjeta_fraude.index, tipo_tarjeta_fraude.values, color = 'skyblue')
plt.xlabel("Tipo de tarjeta")
plt.ylabel("Cantidad")
plt.xticks(rotation = 45, ha = 'right')
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Discover'),
#   Text(1, 0, 'Visa'),
#   Text(2, 0, 'MasterCard'),
#   Text(3, 0, 'American Express')])

# %%
data
# Out:
#       transaction_id  customer_id  merchant_id   amount    transaction_time  \
# 0                  1         1082         2027  5758.59 2023-01-01 00:00:00
# 1                  2         1015         2053  1901.56 2023-01-01 00:00:01
# 2                  3         1004         2035  1248.86 2023-01-01 00:00:02
# 3                  4         1095         2037  7619.05 2023-01-01 00:00:03
# 4                  5         1036         2083  1890.10 2023-01-01 00:00:04
# ...              ...          ...          ...      ...                 ...
# 9995            9996         1056         2023  8935.28 2023-01-01 02:46:35
# 9996            9997         1053         2026    30.15 2023-01-01 02:46:36
# 9997            9998         1041         2034  6333.64 2023-01-01 02:46:37
# 9998            9999         1009         2019  2837.13 2023-01-01 02:46:38
# 9999           10000         1082         2070  7209.43 2023-01-01 02:46:39
#
# ...

# %%
data['customer_id'].value_counts()
# Out:
# customer_id
# 1074    126
# 1085    120
# 1059    118
# 1018    116
# 1099    116
#        ...
# 1027     85
# 1092     84
# 1066     84
# 1003     81
# 1033     81
# Name: count, Length: 100, dtype: int64

# %%
persona_fraudulenta = data[(data['customer_id'] == 1015)]
persona_fraudulenta
# Out:
#       transaction_id  customer_id  merchant_id   amount    transaction_time  \
# 1                  2         1015         2053  1901.56 2023-01-01 00:00:01
# 149              150         1015         2005  9471.97 2023-01-01 00:02:29
# 167              168         1015         2054  3148.54 2023-01-01 00:02:47
# 175              176         1015         2004   615.02 2023-01-01 00:02:55
# 207              208         1015         2062  4776.24 2023-01-01 00:03:27
# ...              ...          ...          ...      ...                 ...
# 9649            9650         1015         2030  2098.67 2023-01-01 02:40:49
# 9654            9655         1015         2027  5175.06 2023-01-01 02:40:54
# 9668            9669         1015         2052  2986.51 2023-01-01 02:41:08
# 9814            9815         1015         2075  2972.41 2023-01-01 02:43:34
# 9872            9873         1015         2098   895.22 2023-01-01 02:44:32
#
# ...

# %%
persona_fraudulenta['is_fraudulent'].value_counts()
# Out:
# is_fraudulent
# 1    56
# 0    47
# Name: count, dtype: int64

# %%
cantidad_robada = data.groupby('is_fraudulent')['amount'].sum().reset_index()
cantidad_robada
# Out:
#    is_fraudulent       amount
# 0              0  24380007.74
# 1              1  25203808.43

# %% [markdown]
# Conclusion > Alrededor de 25millones de dolares robados

# %%
data['amount'].describe()
# Out:
# count    10000.000000
# mean      4958.381617
# std       2899.699675
# min         10.610000
# 25%       2438.175000
# 50%       4943.945000
# 75%       7499.312500
# max       9999.750000
# Name: amount, dtype: float64

# %%
data['card_type'].value_counts()
# Out:
# card_type
# Discover            2633
# American Express    2494
# Visa                2490
# MasterCard          2383
# Name: count, dtype: int64

# %%
data['location'].value_counts()
# Out:
# location
# City-7     223
# City-40    221
# City-41    218
# City-14    218
# City-32    218
# City-24    217
# City-20    215
# City-22    213
# City-4     213
# City-45    211
# City-43    210
# City-5     210
# City-13    209
# City-39    209
# City-12    209
# City-23    209
# City-37    209
# City-25    207
# City-28    207
# City-42    206
# City-47    206
# City-17    205
# City-48    202
# City-50    202
# City-49    202
# City-19    201
# City-9     200
# City-11    199
# City-29    197
# City-46    196
# City-33    196
# City-3     195
# City-10    194
# City-18    194
# City-26    192
# City-30    191
# City-21    191
# City-27    191
# City-38    191
# City-34    191
# City-6     190
# City-44    189
# City-1     188
# City-8     188
# City-16    186
# City-2     185
# City-15    184
# City-31    177
# City-36    167
# City-35    158
# Name: count, dtype: int64

# %%
correlation_amount = data['amount'].corr(data['is_fraudulent'])
print("Correlación entre Amount e is_fraudulent:", correlation_amount)
# Out:
# Correlación entre Amount e is_fraudulent: 0.005155088636297298

# %%
data
# Out:
#       transaction_id  customer_id  merchant_id   amount    transaction_time  \
# 0                  1         1082         2027  5758.59 2023-01-01 00:00:00
# 1                  2         1015         2053  1901.56 2023-01-01 00:00:01
# 2                  3         1004         2035  1248.86 2023-01-01 00:00:02
# 3                  4         1095         2037  7619.05 2023-01-01 00:00:03
# 4                  5         1036         2083  1890.10 2023-01-01 00:00:04
# ...              ...          ...          ...      ...                 ...
# 9995            9996         1056         2023  8935.28 2023-01-01 02:46:35
# 9996            9997         1053         2026    30.15 2023-01-01 02:46:36
# 9997            9998         1041         2034  6333.64 2023-01-01 02:46:37
# 9998            9999         1009         2019  2837.13 2023-01-01 02:46:38
# 9999           10000         1082         2070  7209.43 2023-01-01 02:46:39
#
# ...
